# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances. Think about what each dimension means to find out which dimensions you'll want to perform each operation on.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clones()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
# !pip install torch==1.9.0

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext==0.10.0
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download es_core_news_sm
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp38-cp38-manylinux1_x86_64.whl (831.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.4/831.4 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.9.0) (4.5.0)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.1+cu116 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.13.1+cu116 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# Successfully installed torch-1.9.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.10.0
#   Downloading torchtext-0.10.0-cp38-cp38-manylinux1_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 53.9 MB/s eta 0:00:00
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (1.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.9.0->torchtext==0.10.0) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (2.10)
# Installing collected packages: torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.14.1
#     Uninstalling torchtext-0.14.1:
#       Successfully uninstalled torchtext-0.14.1
# Successfully installed torchtext-0.10.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (23.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.1.2)
# 2023-03-07 03:26:04.279163: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 03:26:07.642727: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-07 03:26:07.643018: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-07 03:26:07.643041: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 53.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.22.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (23.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.25.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2023-03-07 03:26:23.138486: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-07 03:26:24.000942: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-07 03:26:24.001076: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-07 03:26:24.001101: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-core-news-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.4.0/es_core_news_sm-3.4.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 44.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from es-core-news-sm==3.4.0) (3.4.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (6.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (57.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.10.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.4.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.12)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.22.4)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.25.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.1.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (23.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.1.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.1.2)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# --2023-03-07 03:26:35--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  --.-KB/s    in 0.08s
#
# 2023-03-07 03:26:36 (98.4 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2023-03-07 03:26:36--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  --.-KB/s    in 0.09s
#
# 2023-03-07 03:26:36 (85.6 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))
    
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)


    
class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)
    
class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)
 
    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)
    
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ## Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
def attention(query, key, value, mask):
    # Compute 'Scaled Dot Product Attention'
    
    scores = torch.bmm(query, torch.permute(key, (0, 2, 1)))/math.sqrt(query.size(dim=2))
    
    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
        
    output = torch.bmm(F.softmax(scores, dim=2), value)
    
    return output

# %%
class AttentionHead(nn.Module):
    def __init__(self, d_model, dropout=0.1):
        super(AttentionHead, self).__init__()
        
        # Make an attention head (linear layers for q, k, and v)
        #TODO: Dropout instead of linear?
        self.q_lin = nn.Linear(d_model, d_model)
        self.k_lin = nn.Linear(d_model, d_model)
        self.v_lin = nn.Linear(d_model, d_model)

    def forward(self, query, key, value, mask):
        # Pass the query, key, value through their respective layers
        q = self.q_lin(query)
        k = self.k_lin(key)
        v = self.v_lin(value)
        # Compute scaled dot-product attention on the output
        return attention(q, k, v, mask)

class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        self.d_model = d_model
        self.h = h

        self.split_sizes = [self.d_model//self.h for i in range(self.h-1)]
        self.split_sizes.append(self.d_model//self.h + self.d_model % self.h)
        # Implement Multi-head attention mechanism
        
        # Make h copies of the attention head (Hint: See the `clones()` helper function)
        #last head gets any extra rows
        self.heads = clones(AttentionHead(d_model//h), h - 1)
        self.heads.append(AttentionHead(d_model//h + d_model % h))

        self.feed_forward = nn.Linear(d_model, d_model)

    def forward(self, query, key, value, mask):
        # For each attention head concatenate output
        catted = 0

        #print("d_model = {} | h = {} | split_sizes = ".format(self.d_model, self.h), self.split_sizes)
        #print("Shapes:\nquery:{}\nkey:{}\nvalue:{}\nmask:{}".format(query.shape, key.shape, value.shape, mask.shape))
        q_split = torch.split(query, self.split_sizes, dim=2)
        k_split = torch.split(key, self.split_sizes, dim=2)
        v_split = torch.split(value, self.split_sizes, dim=2)
        #mask_split = torch.split(mask, self.split_sizes, dim=2)
        #print("Shapes:\nq_split:{}\nk_split:{}\nv_split:{}".format(q_split.shape, k_split.shape, v_split.shape))
        for i, head_i in enumerate(self.heads):
            # Pass the query, key, value through their respective layers
            if isinstance(catted, int):
                #print("(pre) catted: ", catted)
                catted = head_i(q_split[i], k_split[i], v_split[i], mask)
                #print("(post) catted: ", type(catted))
            else:
                #head_i = head(query, key, value, mask)
                #print("head_i type = ", type(head_i))
                #print("head_i = ", head_i)
                catted = torch.cat((catted, head_i(q_split[i], k_split[i], v_split[i], mask)), 2)
        return self.feed_forward(catted)

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy
        
        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
    
    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
    
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext.legacy import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es_core_news_sm')
spacy_en = spacy.load('en_core_web_sm')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD, 
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
with open('./spanish', 'r', encoding='utf-8') as spanish_text:
  spanish_lines = list(spanish_text)
with open('./english', 'r', encoding='utf-8') as english_text:
  english_lines = list(english_text)

fields = (["src", SRC], ["trg", TGT])
examples = [data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)), 
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)
            
        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)

    
def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg, 
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ## Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 3
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=False)

    model_opt = torch.optim.Adam(model.parameters(), lr=5e-4)
    for epoch in range(n_epochs):
        model.train()
        run_epoch((rebatch(pad_idx, b) for b in train_iter), 
                  model, 
                  LossFunction(model.generator, criterion, model_opt))
        model.eval()
scope()
# Out:
# Epoch Step: 1 Loss: 8.624737 Tokens per Sec: 3137.133789
# Epoch Step: 51 Loss: 6.271412 Tokens per Sec: 8981.475586
# Epoch Step: 101 Loss: 5.408133 Tokens per Sec: 8322.125977
# Epoch Step: 151 Loss: 5.438363 Tokens per Sec: 9568.493164
# Epoch Step: 201 Loss: 4.675722 Tokens per Sec: 8495.625977
# Epoch Step: 251 Loss: 4.725281 Tokens per Sec: 9071.773438
# Epoch Step: 301 Loss: 4.453278 Tokens per Sec: 9738.090820
# Epoch Step: 351 Loss: 4.231134 Tokens per Sec: 8058.668457
# Epoch Step: 401 Loss: 4.656973 Tokens per Sec: 9908.542969
# Epoch Step: 451 Loss: 5.012353 Tokens per Sec: 9620.133789
# Epoch Step: 501 Loss: 3.760837 Tokens per Sec: 8131.416016
# Epoch Step: 551 Loss: 4.616837 Tokens per Sec: 10232.725586
# Epoch Step: 601 Loss: 4.383741 Tokens per Sec: 6447.360840
# Epoch Step: 651 Loss: 4.628702 Tokens per Sec: 9773.070312
# Epoch Step: 701 Loss: 3.470597 Tokens per Sec: 9906.895508
# Epoch Step: 751 Loss: 4.437088 Tokens per Sec: 7940.944336
# Epoch Step: 801 Loss: 4.385040 Tokens per Sec: 9645.125000
# Epoch Step: 851 Loss: 3.949798 Tokens per Sec: 9872.426758
# Epoch Step: 901 Loss: 3.375191 Tokens per Sec: 8393.999023
# Epoch Step: 951 Loss: 3.825796 Tokens per Sec: 9790.398438
# Epoch Step: 1001 Loss: 3.750158 Tokens per Sec: 8709.514648
# Epoch Step: 1051 Loss: 3.862344 Tokens per Sec: 9271.270508
# Epoch Step: 1101 Loss: 3.824750 Tokens per Sec: 9706.082031
# Epoch Step: 1151 Loss: 3.737334 Tokens per Sec: 7951.460449
# Epoch Step: 1201 Loss: 3.472219 Tokens per Sec: 9952.058594
# Epoch Step: 1251 Loss: 3.743786 Tokens per Sec: 9810.485352
# Epoch Step: 1301 Loss: 3.687529 Tokens per Sec: 7888.180176
# Epoch Step: 1 Loss: 3.495199 Tokens per Sec: 3030.564941
# Epoch Step: 51 Loss: 2.880554 Tokens per Sec: 10264.918945
# Epoch Step: 101 Loss: 3.500157 Tokens per Sec: 8633.499023
# Epoch Step: 151 Loss: 3.164409 Tokens per Sec: 9066.744141
# Epoch Step: 201 Loss: 3.172839 Tokens per Sec: 9787.448242
# Epoch Step: 251 Loss: 3.642892 Tokens per Sec: 8003.812988
# Epoch Step: 301 Loss: 3.253161 Tokens per Sec: 9973.116211
# Epoch Step: 351 Loss: 3.557284 Tokens per Sec: 9527.241211
# Epoch Step: 401 Loss: 3.553705 Tokens per Sec: 8208.101562
# Epoch Step: 451 Loss: 2.849329 Tokens per Sec: 9671.132812
# Epoch Step: 501 Loss: 2.492972 Tokens per Sec: 8499.709961
# Epoch Step: 551 Loss: 3.493200 Tokens per Sec: 8833.623047
# Epoch Step: 601 Loss: 2.607538 Tokens per Sec: 9993.675781
# Epoch Step: 651 Loss: 2.826763 Tokens per Sec: 8220.184570
# Epoch Step: 701 Loss: 3.258328 Tokens per Sec: 9153.529297
# Epoch Step: 751 Loss: 2.968849 Tokens per Sec: 8114.940918
# Epoch Step: 801 Loss: 3.269217 Tokens per Sec: 8328.095703
# Epoch Step: 851 Loss: 2.726735 Tokens per Sec: 9632.478516
# Epoch Step: 901 Loss: 3.031709 Tokens per Sec: 7756.508301
# Epoch Step: 951 Loss: 3.905670 Tokens per Sec: 9736.400391
# Epoch Step: 1001 Loss: 2.973626 Tokens per Sec: 9998.986328
# Epoch Step: 1051 Loss: 2.890287 Tokens per Sec: 7811.301758
# Epoch Step: 1101 Loss: 2.483030 Tokens per Sec: 9427.579102
# Epoch Step: 1151 Loss: 2.594970 Tokens per Sec: 9440.209961
# Epoch Step: 1201 Loss: 2.284668 Tokens per Sec: 8275.054688
# Epoch Step: 1251 Loss: 2.758691 Tokens per Sec: 9728.246094
# Epoch Step: 1301 Loss: 3.494193 Tokens per Sec: 8395.286133
# Epoch Step: 1 Loss: 2.584849 Tokens per Sec: 3025.572754
# Epoch Step: 51 Loss: 2.387156 Tokens per Sec: 9760.808594
# Epoch Step: 101 Loss: 2.792659 Tokens per Sec: 9351.570312
# Epoch Step: 151 Loss: 2.777099 Tokens per Sec: 8112.214844
# Epoch Step: 201 Loss: 1.912670 Tokens per Sec: 9857.574219
# Epoch Step: 251 Loss: 2.522600 Tokens per Sec: 9243.806641
# Epoch Step: 301 Loss: 2.217142 Tokens per Sec: 8636.222656
# Epoch Step: 351 Loss: 2.270614 Tokens per Sec: 10083.791992
# Epoch Step: 401 Loss: 2.427017 Tokens per Sec: 8169.107422
# Epoch Step: 451 Loss: 1.901934 Tokens per Sec: 9739.396484
# Epoch Step: 501 Loss: 2.199291 Tokens per Sec: 9851.947266
# Epoch Step: 551 Loss: 2.124974 Tokens per Sec: 8206.850586
# Epoch Step: 601 Loss: 2.481883 Tokens per Sec: 9891.362305
# Epoch Step: 651 Loss: 2.098340 Tokens per Sec: 9642.786133
# Epoch Step: 701 Loss: 2.046184 Tokens per Sec: 8246.688477
# Epoch Step: 751 Loss: 1.674690 Tokens per Sec: 9633.880859
# Epoch Step: 801 Loss: 2.331296 Tokens per Sec: 8724.689453
# Epoch Step: 851 Loss: 2.858208 Tokens per Sec: 8985.478516
# Epoch Step: 901 Loss: 2.607835 Tokens per Sec: 10045.042969
# Epoch Step: 951 Loss: 2.631130 Tokens per Sec: 7828.898926
# Epoch Step: 1001 Loss: 2.229884 Tokens per Sec: 9577.458008
# Epoch Step: 1051 Loss: 2.032229 Tokens per Sec: 9923.654297
# Epoch Step: 1101 Loss: 2.400976 Tokens per Sec: 7858.104004
# Epoch Step: 1151 Loss: 2.597686 Tokens per Sec: 9448.293945
# Epoch Step: 1201 Loss: 1.824011 Tokens per Sec: 8971.126953
# Epoch Step: 1251 Loss: 2.887464 Tokens per Sec: 8616.881836
# Epoch Step: 1301 Loss: 2.113567 Tokens per Sec: 9836.111328

# %% [markdown]
# ## Translate

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	De los Setenta
# Translation:	Of the Seventy
# Target:		Of the Seventy
#
# Spanish:	Venga tu reino
# Translation:	Thy kingdom come into thy kingdom
# Target:		Thy Kingdom Come
#
# Spanish:	Véase Juan <unk> .
# Translation:	See John 6:35 .
# Target:		See John <unk> .
#
# Spanish:	Informe estadístico de 2011
# Translation:	Statistical Report , 2011
# Target:		Statistical Report , 2011
#
# Spanish:	Élder Kevin W. Pearson
# Translation:	Elder Kevin W. Kevin W. Gong
# Target:		Elder Kevin W. Pearson
#
# Spanish:	No puede hacerlo .
# Translation:	Not so can do n’t do .
# Target:		He can not do it .
#
# Spanish:	Los misioneros pueden ayudar .
# Translation:	missionaries can help them .
# Target:		Missionaries can help .
#
# Spanish:	Doctrina y Convenios 3:3 .
# Translation:	Doctrine and Covenants 64:33 .
# Target:		Doctrine and Covenants 3:3 .
#
# Spanish:	Doctrina y Convenios 121:46 .
# Translation:	Doctrine and Covenants 52:14 .
# Target:		Doctrine and Covenants 121:46 .
#
# Spanish:	Juan 20:5 , 7 .
# Translation:	John Greenleaf Whittier , 7 .
# Target:		John 20:5 , 7 .
#
# Spanish:	Vemos que está ocupada y
# Translation:	We see that we are going and a familiar and we see and see that we see .
# Target:		We can see you are busy .
#
# Spanish:	Sesión del sábado por la mañana
# Translation:	Saturday Afternoon Session
# Target:		Saturday Morning Session
#
# Spanish:	Las Escrituras en la conferencia general
# Translation:	The scriptures teach in general conference
# Target:		The Scriptures in General Conference
#
# Spanish:	Por el élder L. Tom Perry
# Translation:	By Elder L. Tom Perry
# Target:		By Elder L. Tom Perry
#
# Spanish:	Véase Doctrina y Convenios 93:36–40 .
# Translation:	See Doctrine and Covenants 87:8 .
# Target:		See Doctrine and Covenants 93:36–40 .
#
# Spanish:	Primer Consejero de la Primera Presidencia
# Translation:	First Counselor in the First Presidency
# Target:		First Counselor in the First Presidency
#
# Spanish:	Esos días se han ido .
# Translation:	Those days have been gone before .
# Target:		Those days are now gone .
#
# Spanish:	Del Quórum de los Doce Apóstoles
# Translation:	Of the Quorum of the Twelve Apostles
# Target:		Of the Quorum of the Twelve Apostles
#
# Spanish:	Con mucha frustración decidí regresar .
# Translation:	With much to return to return .
# Target:		With great frustration , I decided to go back .
#
# Spanish:	Presentado por el presidente Dieter F. Uchtdorf
# Translation:	Presented by President Dieter F. Uchtdorf
# Target:		Presented by President Dieter F. Uchtdorf
#
# Spanish:	Doctrina y Convenios 121:45 , 46 .
# Translation:	Doctrine and Covenants 121:45 , 46 .
# Target:		Doctrine and Covenants 121:45 , 46 .
#
# Spanish:	Dirige : Presidente Dieter F. Uchtdorf .
# Translation:	Conducting : President Dieter F. Uchtdorf .
# Target:		Conducting : President Dieter F. Uchtdorf .
#
# Spanish:	Preguntas como ¿ De dónde venimos ?
# Translation:	Where as we come from the waters of ?
# Target:		Questions like Where did we come from ?
#
# Spanish:	Presidente del Cuórum de los Doce Apóstoles
# Translation:	President of the Quorum of the Twelve Apostles
# Target:		President of the Quorum of the Twelve Apostles
#
# Spanish:	Nunca es demasiado pronto ni demasiado tarde
# Translation:	It is never too late too late to never too late .
# Target:		It ’s Never Too Early and It ’s Never Too Late
#
# Spanish:	Esto nos tomó un poco por sorpresa .
# Translation:	This would come to a little surprise for us .
# Target:		This was a bit unexpected .
#
# Spanish:	Correspondencia personal de la autora , 2012 .
# Translation:	Personal correspondence , 2012 , 2012 .
# Target:		Personal correspondence to author , 2012 .
#
# Spanish:	Testifico que la vida es una dádiva .
# Translation:	I testify that life is a gift .
# Target:		I testify that life is a gift .
#
# Spanish:	¡ Qué verdad tan clara y sencilla !
# Translation:	What truth is clear and simple !
# Target:		What a simple and clear truth it was !
#
# Spanish:	El Señor necesita que cambien el mundo .
# Translation:	The Lord needs you to find the world .
# Target:		The Lord needs you to change the world .
#
# Spanish:	siento que “ estoy en casa ” ;
# Translation:	I am “ I am in the home . ”
# Target:		I have a feeling of “ being home ” ;
#
# Spanish:	“ No ” , dijo el médico .
# Translation:	“ No , ” he said the doctor .
# Target:		“ No , ” said the doctor , “ I do n’t dance .
#
# Spanish:	En el país se impuso la ley <unk> .
# Translation:	In the country was taken by the law of the law .
# Target:		The country was under <unk> law .
#
# Spanish:	Sin duda hemos sentido ese espíritu esta noche .
# Translation:	None of this spirit we have felt tonight .
# Target:		We have surely felt that spirit tonight .
#
# Spanish:	3 Nefi 17:3 ; véase también Moroni 10:3 .
# Translation:	3 Nephi 17:3 ; see also Moroni 10:32–33 .
# Target:		3 Nephi 17:3 ; see also Moroni 10:3 .
#
# Spanish:	Después del accidente , Sailor tuvo que elegir .
# Translation:	After the accident , Sailor had a choose to choose .
# Target:		After the crash , Sailor had a choice .
#
# Spanish:	Las autoridades <unk> todas las copias que encontraban .
# Translation:	The scope of all were presented to the midst of the midst of them .
# Target:		The authorities burned all the copies they could find .
#
# Spanish:	En muchos sentidos , estamos lejos de casa ;
# Translation:	In many , there are far away from home .
# Target:		In many ways , we are far from home .
#
# Spanish:	Hablo de este tema desde una perspectiva particular .
# Translation:	I speak of this subject from a particular perspective .
# Target:		I speak about this topic from a <unk> distinctive perspective .
#
# Spanish:	Cómo preservar el albedrío y cómo proteger la libertad religiosa
# Translation:	How to protect and protect the religious liberty and freedom to protect religious liberty
# Target:		Preserving Agency , Protecting Religious Freedom
#
# Spanish:	Todo iba bien hasta que cumplí los doce años .
# Translation:	All in my age I went to my 12 .
# Target:		All was well until I turned 12 .
#
# Spanish:	El Salvador es la fuente de la paz verdadera .
# Translation:	The Savior is the source of peace .
# Target:		The Savior is the source of true peace .
#
# Spanish:	Dios envía mensajes y mensajeros autorizados a Sus hijos .
# Translation:	God sends messengers and authorized messengers to His children .
# Target:		God sends messages and authorized messengers to His children .
#
# Spanish:	Ése es el tono de Dios cuando habla seriamente .
# Translation:	This is the righteous of God when he speaks to .
# Target:		That is language God uses when He means business .
#
# Spanish:	Ann Rowley vivía el Evangelio con gran sacrificio personal .
# Translation:	Ann Dibb , a great sacrifice with great sacrifice .
# Target:		Ann Rowley was living the gospel at great personal sacrifice .
#
# Spanish:	¿ Nos recuerda esa historia las palabras del Salvador ?
# Translation:	Do we have reminded of that the words of the Savior ?
# Target:		Does this story remind us of the words of the Savior ?
#
# Spanish:	Ante mis deseos de llegar , decidí continuar solo .
# Translation:	I had my desires to continue to continue only too .
# Target:		Because of my desire to get there , I decided to continue on alone .
#
# Spanish:	El mensaje que tengo para ustedes esta noche es directo .
# Translation:	The message I have to you tonight is a direct .
# Target:		My message to you tonight is straightforward .
#
# Spanish:	Mi madre nunca dejó de amar y preocuparse por Susan .
# Translation:	My mother never stopped to love and encourage Susan .
# Target:		My mother never stopped loving and caring for Susan .
#
# Spanish:	Nadie lo ha evitado , y pocas personas lo superan .
# Translation:	No one has been offended , and few people .
# Target:		No one has avoided it ; few overcome it .
#
# Spanish:	Estoy seguro de que fue una prueba de su fe .
# Translation:	I am sure that she was a test of faith .
# Target:		I ’m sure it was a trial of their faith .
#
# Spanish:	Véanse Alma 5:21 , 27 ; Doctrina y Convenios <unk> .
# Translation:	See Alma 7:11–12 , Doctrine and Covenants 50:14 .
# Target:		See Alma 5:21 , 27 ; Doctrine and Covenants <unk> .
#
# Spanish:	El misionero no lo podía creer … sus ojos brillaron .
# Translation:	The missionary could not believe his eyes … your eyes .
# Target:		The missionary could n’t believe it . His eyes were shining .
#
# Spanish:	Mostremos nuestra fe en el Señor al pagar nuestros diezmos .
# Translation:	May our faith in the Lord to pay our tithing .
# Target:		Let us show our faith in the Lord by paying our tithing .
#
# Spanish:	El proceso comienza al estar convertidos al evangelio de Jesucristo .
# Translation:	The process begins to be converted to the gospel of Jesus Christ .
# Target:		The process begins with being converted to the gospel of Jesus Christ .
#
# Spanish:	“ ni un pajarillo cae a tierra sin saberlo vuestro Padre
# Translation:	“ neither a mountain to the earth without your Father .
# Target:		“ Not … one sparrow shall … fall to the ground without your Father knowing .
#
# Spanish:	¡ Cuán preciosas son las almas de los hombres ! ” .
# Translation:	How precious are precious souls ! ”
# Target:		How precious are the souls of men ! ”
#
# Spanish:	¿ Por qué creen que el Libro de Mormón es Escritura ?
# Translation:	Why believe the Book of Mormon is the scripture ?
# Target:		Why do you believe the Book of Mormon is scripture ?
#
# Spanish:	El primero fue un hermoso árbol de Navidad en su niñez .
# Translation:	The first was a beautiful tree of Christmas in her mother .
# Target:		The first was a beautiful Christmas tree of his youth .
#
# Spanish:	Manual 2 : Administración de la Iglesia , 2010 , <unk> .
# Translation:	Handbook 2 : Administering the Church ( 2010 ) , 1.3.1 .
# Target:		Handbook 2 : Administering the Church ( 2010 ) , <unk> .
#
# Spanish:	Véase Lucas 22:44 ; Mosíah 3:7 ; Doctrina y Convenios 19:18 .
# Translation:	See Luke 21:19 ; Mosiah 3:7 ; Doctrine and Covenants 64:33 .
# Target:		See Luke 22:44 ; Mosiah 3:7 ; Doctrine and Covenants 19:18 .
#
# Spanish:	Los requerimientos de Su plan son gloriosos , misericordiosos y rigurosos .
# Translation:	The key to His plan are glorious , and we will be able to be resurrected .
# Target:		The requirements of His plan are glorious , merciful , and rigorous .
#
# Spanish:	He acabado la obra que me diste que hiciese ’ ” .
# Translation:	I have the work that which would come to the work . ”
# Target:		I have finished the work which thou gavest me to do . ’ ”
#
# Spanish:	“ tengo otras ovejas que no son de este redil ” .
# Translation:	“ I have no sheep that are not of this fold . ”
# Target:		“ And other sheep I have , which are not of this fold . ”
#
# Spanish:	No nos <unk> con dónde estamos , pero tampoco nos <unk> .
# Translation:	We do n’t miss where we are not , but we did not fail .
# Target:		Let us not be content with where we are , but neither let us be discouraged .
#
# Spanish:	Compartir lo que entiendan , así como ideas , experiencias y testimonios .
# Translation:	Helen Keller , how inspired ideas , experiences , experiences , and testimonies .
# Target:		Share understanding , ideas , experiences , and testimonies .
#
# Spanish:	“ el templo ha llegado a ser una parte de mí ” ;
# Translation:	“ Temple has come to be a part of me . ”
# Target:		“ The temple has become a part of me ” ;
#
# Spanish:	El presidente Thomas S. Monson está viendo esta reunión desde su hogar .
# Translation:	President Thomas S. Monson is listening to this meeting from his home .
# Target:		President Thomas S. Monson is viewing this meeting at his home .
#
# Spanish:	La pureza será la protección de ustedes y la de sus hijos .
# Translation:	Your purity will be protection and the protection from your children .
# Target:		Purity will be your protection and the protection of your children .
#
# Spanish:	F. Scott <unk> , El Gran <unk> , 1925 , pág. 180 .
# Translation:	Orson F. Whitney , The Great Britain , May 1944 , 92 .
# Target:		F. Scott <unk> , The Great <unk> ( 1925 ) , 180 .
#
# Spanish:	Cuando oran , ¿ están realmente orando o solo están pronunciando palabras ?
# Translation:	When you pray , you are praying or praying only praying only with words ?
# Target:		When you pray , are you really praying or just saying prayers ?
#
# Spanish:	Personalmente , pienso en ustedes , la noble juventud de la Iglesia .
# Translation:	I am grateful to you , the noble youth of the Church .
# Target:		<unk> , I think of you — the noble youth of the Church .
#
# Spanish:	De esas maneras tiernas pero poderosas , edificamos el Reino de Dios .
# Translation:	In those things , we build strong , we build the kingdom of God .
# Target:		In these tender yet powerful ways , we build the kingdom of God .
#
# Spanish:	Todo tenía un nombre , y cada nombre <unk> un nuevo pensamiento .
# Translation:	Every name was a name , and every one day will take a new thought .
# Target:		Everything had a name , and each name gave birth to a new thought .
#
# Spanish:	Ella escribió : " Me impresionó la forma en que se presentó .
# Translation:	She wrote : " I was the way about the way .
# Target:		She wrote : " I was enlightened by the way he presented himself to me .
#
# Spanish:	“ Cantemos todos a Jesús ” , Himnos , nro . 109 .
# Translation:	“ Let all come to all , ” Hymns , no .
# Target:		“ We ’ll Sing All Hail to Jesus ’ Name , ” Hymns , no . 182 .
#
# Spanish:	La cultura es un tema del que se habla mucho en la actualidad .
# Translation:	The culture is a subject of today .
# Target:		Culture is much discussed in today ’s world .
#
# Spanish:	Es preciso que nos <unk> tanto a nuestras raíces como a nuestras ramas .
# Translation:	It is that we are careful to be careful ourselves as our branches .
# Target:		We need to be connected to both our roots and branches .
#
# Spanish:	Él verdaderamente es nuestro Padre , y es un ser personal y real .
# Translation:	He truly is our Father , and is a personal personal .
# Target:		He is indeed our Father , and He is personal and real .
#
# Spanish:	Nuestra familia se crió en la elevada región desértica del sur de Utah .
# Translation:	Our family grew up in the United States Air Force .
# Target:		Our family grew up in the high desert country of southern Utah .
#
# Spanish:	¿ Qué estamos dispuestos a dar para ser limpios y recibir ese gozo ?
# Translation:	What are willing to be willing to be clean and receive joy ?
# Target:		What are we willing to give to be clean and receive that joy ?
#
# Spanish:	Y cuando tengan mi edad , se darán cuenta de eso aún más .
# Translation:	And when my age , you will be more than more than you .
# Target:		And when you are my age , you will realize this even more .
#
# Spanish:	Cuando era joven , mi padre me llevó al estadio de los Yankees .
# Translation:	When I was young , my father took me to the name of the name of the name of the young man .
# Target:		When I was growing up , my father drove me to <unk> Stadium .
#
# Spanish:	La influencia de Santo Espíritu nos mejora , fortalece , enseña y guía .
# Translation:	The Holy Ghost is something , strengthens , guide , and guide us .
# Target:		The Holy Spirit ’s influence improves , strengthens , teaches , and guides us .
#
# Spanish:	Especialmente emocionantes para mis muchos , muchos familiares en el Estado de Wyoming .
# Translation:	Almost for my many , many , many of the United States .
# Target:		Especially it was exciting for my many , many relatives in the state of Wyoming .
#
# Spanish:	El investigador resultó ser <unk> de radio y le encantó recibir ese mensaje .
# Translation:	The scope of the radio and his radio , he will receive this message .
# Target:		The investigator happened to be a radio <unk> and was delighted to receive the message .
#
# Spanish:	“ Sabemos que Él quiere lo mejor para nosotros y seremos bendecidos ” .
# Translation:	“ We know that He wants us to do and blessed us . ”
# Target:		“ We know He has our best interests at heart , and we will be blessed . ”
#
# Spanish:	Nuestras obras y deseos por sí solos no nos salvan ni pueden hacerlo .
# Translation:	Our works and desires for us not alone can not save us .
# Target:		In truth , we can not be good enough or measure up relying solely upon our own capacity and performance .
#
# Spanish:	Recordarán la forma en que el rey Benjamín explicó su propia función de liderazgo :
# Translation:	You will remember the word of King Benjamin explained to his own role :
# Target:		You remember how King Benjamin explained his own leadership role :
#
# Spanish:	La nueva tecnología hace que sea más fácil que nunca cumplir con esa responsabilidad .
# Translation:	The new technology is easier to be easier to fulfill this responsibility to fulfill this responsibility .
# Target:		New technology makes it easier than ever to fulfill that responsibility .
#
# Spanish:	En la vida terrenal , constantemente cometemos errores y quebrantamos las leyes de Dios ;
# Translation:	In mortality we gain mistakes , we will gain mistakes and gain the laws of God .
# Target:		In mortality , we invariably make mistakes and violate God ’s laws .
#
# Spanish:	El maravilloso libro del senador <unk> describe el sabbat judío y aporta ideas inspiradoras .
# Translation:	The wonderful book of the book includes the Old Testament and provides prophetic messages .
# Target:		<unk> <unk> ’s delightful book describes the Jewish Shabbat and provides inspirational insights .
#
# Spanish:	Aun los niños muy pequeños pueden comprender y aceptar las cosas de naturaleza eterna .
# Translation:	Even though little children can understand and accept the things of eternal nature .
# Target:		Even very young children can understand and accept things of an eternal nature .
#
# Spanish:	Henry B. Eyring , To Draw Closer to God , 1997 , pág. 88 .
# Translation:	Henry B. Eyring , To Draw Closer to God ( 1997 ) , 93 .
# Target:		Henry B. Eyring , To Draw Closer to God ( 1997 ) , 88 .
#
# Spanish:	Él hablará de una manera que es inconfundible y que trasciende la experiencia humana .
# Translation:	He will speak of a way that is not to the human experience .
# Target:		He will speak in a way that is unmistakable and that transcends human experience .
#
# Spanish:	Octavo , no debemos tener para los demás estándares más altos que los nuestros .
# Translation:	We should not have to have the other faiths to the more than our lives .
# Target:		Eighth , we should not have higher standards for others than we do for ourselves .
#
# Spanish:	El Salvador ha prometido ángeles a nuestra diestra y a nuestra siniestra para sostenernos .
# Translation:	The Savior has promised angels to our right hand and in our hand .
# Target:		The Savior has promised angels on our left and our right to bear us up .
#
# Spanish:	Recuerden , al tender la mano a cada hermana o hermano , bendecimos generaciones .
# Translation:	Remember , to her hand , Sister sister or her mother , will come to the generations .
# Target:		Please remember : as we reach out to each sister or brother , we bless generations .
#
# Spanish:	Poseemos este poder del sacerdocio , y todos debemos estar preparados para usarlo debidamente .
# Translation:	We have this power of priesthood , and we must be prepared to use it to use it .
# Target:		We have this priesthood power , and we should all be prepared to use it properly .
#
# Spanish:	Hace apenas un año que anuncié la reducción en la edad del servicio misional .
# Translation:	Some of a year I was born in the age of the missionary service .
# Target:		It has scarcely been one year since I announced the lowering of the age of missionary service .
#
# Spanish:	Un antiguo proverbio dice : “ El que mucho abarca , poco <unk> ” .
# Translation:	A Mormon tells : “ The Great - Control , ” she would be no .
# Target:		An old proverb says , “ If you chase two rabbits , you wo n’t catch either one . ”
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-3232d09dd0f5> in <module>
#      23     src = batch.src.transpose(0, 1)[:1].cuda()
#      24     src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
# ---> 25     out = greedy_decode(model, src, src_mask,
#      26                         max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
#      27     print("Spanish:", end="\t")
#
# <ipython-input-15-3232d09dd0f5> in greedy_decode(model, src, src_mask, max_len, start_symbol)
#       3     ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
#       4     for i in range(max_len-1):
# ----> 5         out = model.decode(memory, src_mask,
#       6                            Variable(ys),
#       7                            Variable(subsequent_mask(ys.size(1))
#
# <ipython-input-9-06582146a7ac> in decode(self, memory, src_mask, tgt, tgt_mask)
#      30
#      31     def decode(self, memory, src_mask, tgt, tgt_mask):
# ---> 32         return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-4-a48d279d1123> in forward(self, x, memory, src_mask, tgt_mask)
#       8     def forward(self, x, memory, src_mask, tgt_mask):
#       9         for layer in self.layers:
# ---> 10             x = layer(x, memory, src_mask, tgt_mask)
#      11         return self.norm(x)
#      12
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-4-a48d279d1123> in forward(self, x, memory, src_mask, tgt_mask)
#      25         m = memory
#      26         x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
# ---> 27         x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
#      28         return self.sublayer[2](x, self.feed_forward)
#      29
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-2-c1f8275b2cba> in forward(self, x, sublayer)
#      54     def forward(self, x, sublayer):
#      55         "Apply residual connection to any sublayer with the same size."
# ---> 56         return x + self.dropout(sublayer(self.norm(x)))
#      57
#      58 def clones(module, N):
#
# <ipython-input-4-a48d279d1123> in <lambda>(x)
#      25         m = memory
#      26         x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
# ---> 27         x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
#      28         return self.sublayer[2](x, self.feed_forward)
#      29
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-6-2ac23a3d9cd0> in forward(self, query, key, value, mask)
#      49             if isinstance(catted, int):
#      50                 #print("(pre) catted: ", catted)
# ---> 51                 catted = head_i(q_split[i], k_split[i], v_split[i], mask)
#      52                 #print("(post) catted: ", type(catted))
#      53             else:
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# KeyboardInterrupt:
